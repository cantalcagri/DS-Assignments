# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df = pd.read_csv('store_sharing.csv')
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.isna().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
# season

# %%
sns.countplot(data = df, x = 'season');

# %%
# is_holiday

# %%
sns.countplot(data = df, x = 'is_holiday');

# %%
# is_weekend
sns.countplot(data = df, x = 'is_weekend');

# %%
sns.countplot(data = df, x = 'weather_code');

# %%
# weather_code

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.timestamp.dtype
# Out:
# dtype('O')

# %%
df.timestamp = df.timestamp.apply(pd.to_datetime)

# %%
df.timestamp.dtype.type
# Out:
# numpy.datetime64

# %%
df.set_index(df.timestamp, inplace=True)

# %%
df.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df['year'] = df.timestamp.dt.year

# %%
df.drop('Year', axis =1 , inplace= True)

# %%
df.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season  year  \
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0  2015
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0  2015
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0  2015
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0  2015
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0  2015
#
#                      month  day_of_month  days_of_week  hour
# timestamp
# 2015-01-04 00:00:00      1            31             6     0
# 2015-01-04 01:00:00      1            31             6     1
# 2015-01-04 02:00:00      1            31             6     2
# 2015-01-04 03:00:00      1            31             6     3
# 2015-01-04 04:00:00      1            31             6     4

# %%
df['month'] = df.timestamp.dt.month

# %%
df['day_of_month'] = df.timestamp.dt.days_in_month

# %%
df['days_of_week'] = df.timestamp.dt.day_of_week

# %%
df['hour'] = df.timestamp.dt.hour

# %%
df['season'] = df.timestamp.dt.

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  day_of_month  day_of_week  hour
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...             4            6     0
# 2015-01-04 01:00:00  138  3.0  2.5  ...             4            6     1
# 2015-01-04 02:00:00  134  2.5  2.5  ...             4            6     2
# 2015-01-04 03:00:00   72  2.0  2.0  ...             4            6     3
# 2015-01-04 04:00:00   47  2.0  0.0  ...             4            6     4
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
df2 = df.copy()

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2.drop('timestamp', axis = 1, inplace = True)

# %%
df2
# Out:
#         cnt   t1   t2    hum  wind_speed  weather_code  is_holiday  \
# 0       182  3.0  2.0   93.0         6.0           3.0         0.0
# 1       138  3.0  2.5   93.0         5.0           1.0         0.0
# 2       134  2.5  2.5   96.5         0.0           1.0         0.0
# 3        72  2.0  2.0  100.0         0.0           1.0         0.0
# 4        47  2.0  0.0   93.0         6.5           1.0         0.0
# ...     ...  ...  ...    ...         ...           ...         ...
# 17409  1042  5.0  1.0   81.0        19.0           3.0         0.0
# 17410   541  5.0  1.0   81.0        21.0           4.0         0.0
# 17411   337  5.5  1.5   78.5        24.0           4.0         0.0
# 17412   224  5.5  1.5   76.0        23.0           4.0         0.0
# 17413   139  5.0  1.0   76.0        22.0           2.0         0.0
#
#        is_weekend  season  year  month  day_of_month  days_of_week  hour
# 0             1.0     3.0  2015      1            31             6     0
# 1             1.0     3.0  2015      1            31             6     1
# 2             1.0     3.0  2015      1            31             6     2
# 3             1.0     3.0  2015      1            31             6     3
# 4             1.0     3.0  2015      1            31             6     4
# ...           ...     ...   ...    ...           ...           ...   ...
# 17409         0.0     3.0  2017      1            31             1    19
# 17410         0.0     3.0  2017      1            31             1    20
# 17411         0.0     3.0  2017      1            31             1    21
# 17412         0.0     3.0  2017      1            31             1    22
# 17413         0.0     3.0  2017      1            31             1    23
#
# [17414 rows x 14 columns]

# %%
plt.figure(figsize = (15,10))
           
sns.heatmap(df2.corr(), cmap = 'coolwarm', annot = True)
# Out:
# <AxesSubplot:>

# %%
# for all variables

# %%
df.drop('timestamp', axis = 1, inplace = True)

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
# ...                         ...         ...     ...   ...    ...
# 2017-01-03 19:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 20:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 21:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 22:00:00         0.0         0.0     3.0  2017      1
# 2017-01-03 23:00:00         0.0         0.0     3.0  2017      1
#
#                      day_of_month  days_of_week  hour
# timestamp
# 2015-01-04 00:00:00            31             6     0
# 2015-01-04 01:00:00            31             6     1
# 2015-01-04 02:00:00            31             6     2
# 2015-01-04 03:00:00            31             6     3
# 2015-01-04 04:00:00            31             6     4
# ...                           ...           ...   ...
# 2017-01-03 19:00:00            31             1    19
# 2017-01-03 20:00:00            31             1    20
# 2017-01-03 21:00:00            31             1    21
# 2017-01-03 22:00:00            31             1    22
# 2017-01-03 23:00:00            31             1    23
#
# [17414 rows x 14 columns]

# %%
x1 = df.corr()[['cnt']].sort_values(by=['cnt'], ascending = False )
plt.figure(figsize= (2,8))
sns.heatmap(x1, annot = True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
# for the target variable

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
plt.figure(figsize=(16,8))
x1.plot.barh(figsize=(12,8), legend = False)
# Out:
# <AxesSubplot:>

# %%
# Out:
#                    cnt
# cnt           1.000000
# t1            0.388798
# t2            0.369035
# hour          0.324423
# wind_speed    0.116295
# month         0.063757
# day_of_month  0.050570
# year          0.010046
# is_holiday   -0.051698
# days_of_week -0.068688
# is_weekend   -0.096499
# season       -0.116180
# weather_code -0.166633
# hum          -0.462901

# %%
#with pandas

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
sns.barplot(data= df, x = )

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
df['year_month'] = df['year'].astype(str) + "-" + df.month.astype(str)
df.year_month
# Out:
# timestamp
# 2015-01-04 00:00:00    2015-1
# 2015-01-04 01:00:00    2015-1
# 2015-01-04 02:00:00    2015-1
# 2015-01-04 03:00:00    2015-1
# 2015-01-04 04:00:00    2015-1
#                         ...
# 2017-01-03 19:00:00    2017-1
# 2017-01-03 20:00:00    2017-1
# 2017-01-03 21:00:00    2017-1
# 2017-01-03 22:00:00    2017-1
# 2017-01-03 23:00:00    2017-1
# Name: year_month, Length: 17414, dtype: object

# %%
df_new = df.copy()
df_new['year_month'] = df_new.index.strftime('%Y-%m')
df_new.year_month
# Out:
# timestamp
# 2015-01-04 00:00:00    2015-01
# 2015-01-04 01:00:00    2015-01
# 2015-01-04 02:00:00    2015-01
# 2015-01-04 03:00:00    2015-01
# 2015-01-04 04:00:00    2015-01
#                         ...
# 2017-01-03 19:00:00    2017-01
# 2017-01-03 20:00:00    2017-01
# 2017-01-03 21:00:00    2017-01
# 2017-01-03 22:00:00    2017-01
# 2017-01-03 23:00:00    2017-01
# Name: year_month, Length: 17414, dtype: object

# %%
df.Month
# Out:
# timestamp
# 2015-01-04 00:00:00    1
# 2015-01-04 01:00:00    1
# 2015-01-04 02:00:00    1
# 2015-01-04 03:00:00    1
# 2015-01-04 04:00:00    1
#                       ..
# 2017-01-03 19:00:00    1
# 2017-01-03 20:00:00    1
# 2017-01-03 21:00:00    1
# 2017-01-03 22:00:00    1
# 2017-01-03 23:00:00    1
# Name: Month, Length: 17414, dtype: int64

# %%
df_new.year_month.value_counts()
# Out:
# 2015-05    744
# 2016-01    744
# 2015-08    744
# 2016-12    744
# 2016-05    744
# 2016-10    743
# 2016-07    741
# 2016-08    740
# 2015-12    740
# 2015-07    740
# 2015-03    739
# 2015-10    736
# 2016-03    729
# 2016-04    719
# 2016-11    719
# 2015-04    719
# 2015-06    717
# 2015-11    711
# 2015-09    711
# 2016-06    705
# 2016-02    688
# 2016-09    683
# 2015-02    671
# 2015-01    671
# 2017-01     72
# Name: year_month, dtype: int64

# %%
my_x = df_new.year_month.value_counts().sort_index()
my_y = df_new.cnt.groupby(df_new['year_month']).sum()

# %%
my_y.shape
# Out:
# (25,)

# %%
plt.figure(figsize = (15, 5), dpi = 100)
sns.lineplot(x = my_x.index, y = my_y.values)
plt.xticks(rotation = 90);
plt.xlabel('year_month')
plt.ylabel('cnt');

# %%
plt.figure(figsize=(20,5))

sns.lineplot(data = df_new, x = 'year_month', y = 'cnt');

# %%
# with lineplot

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data = df_new, x = 'month', y = 'cnt');

# %%
# with lineplot

# %%
plt.figure(figsize=(20,5))

sns.pointplot(x='month', y = 'cnt', data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %%
# with pointplot

# %%
plt.figure(figsize=(20,5))

sns.barplot(x='month', y = 'cnt', data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %%
# with barplot

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data = df_new, x = 'hour', y = 'cnt', hue = 'is_holiday');

# %%
# with lineplot (*whether it is a holiday or not*)

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data = df_new, x = 'hour', y = 'cnt', hue = 'season');

# %%
# with lineplot (*You may want to see seasonal breakdowns*)

# %%
plt.figure(figsize=(20,5))
sns.pointplot(data = df_new, x = 'hour', y = 'cnt');

# %%
plt.figure(figsize=(20,5))
sns.pointplot(data = df_new, x = 'hour', y = 'cnt', hue = 'is_weekend');

# %%
plt.figure(figsize=(20,5))
sns.pointplot(data = df_new, x = 'hour', y = 'cnt', hue = 'is_weekend');

# %%
plt.figure(figsize=(20,5))
sns.pointplot(data = df_new, x = 'hour', y = 'cnt', hue = 'season');

# %%
# with pointplot

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
sns.barplot(data = df_new, x = 'days_of_week', y = 'cnt', hue = 'is_weekend');

# %%
# with barplot

# %%
plt.figure(figsize=(20,5))
sns.pointplot(data = df_new, x = 'days_of_week', y = 'cnt');

# %%
plt.figure(figsize=(20,5))
sns.pointplot(data = df_new, x = 'days_of_week', y = 'cnt', hue = 'season');

# %%
# with pointplot

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
plt.figure(figsize=(20,5))
sns.lineplot(data = df_new, x = 'day_of_month', y = 'cnt');

# %%
df_new.cnt.groupby(df_new['day_of_month']).sum()
# Out:
# day_of_month
# 28      543594
# 29      592910
# 30     6839845
# 31    11929623
# Name: cnt, dtype: int64

# %%
df_new ['day_month'] = df.index.day
df_new.day_month
# Out:
# timestamp
# 2015-01-04 00:00:00    4
# 2015-01-04 01:00:00    4
# 2015-01-04 02:00:00    4
# 2015-01-04 03:00:00    4
# 2015-01-04 04:00:00    4
#                       ..
# 2017-01-03 19:00:00    3
# 2017-01-03 20:00:00    3
# 2017-01-03 21:00:00    3
# 2017-01-03 22:00:00    3
# 2017-01-03 23:00:00    3
# Name: day_month, Length: 17414, dtype: int64

# %%
plt.figure(figsize=(18,7), dpi = 150)
sns.lineplot(data = df_new, x = 'day_month', y = 'cnt');

# %%
#with lineplot
# Out:
# day_of_month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1128  1144  1141  ...  1131  1063  1080  1156  968
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
plt.figure(figsize=(15,8), dpi = 50)

sns.barplot(data = df_new, x = 'year', y = 'cnt');

# %%
# with barplot

# %%
plt.figure(figsize=(15,8))

sns.barplot(data = df_new, x = 'season', y = 'cnt');

# %%
# with barplot

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
def my_weekend(a):
    if a == 0.0:
        return 'weekday'
    else:
        return 'weekend'

# %%
df_new.is_weekend = df_new.is_weekend.apply(my_weekend)

# %%
df_new.groupby(df_new['is_weekend']).sum().plot(kind= 'pie', y = 'cnt', legend = False, autopct = '%1.1f%%', figsize=(8,8))
plt.ylabel('');

# %%
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
# pie chart

# %%
g = sns.countplot(data = df, x = 'is_weekend')

for p in g.ax.patches:
    txt = str(p.get_height().round(2))+

# %%
# with countplot

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
sns.countplot(data = df_new, x = 'weather_code')
# Out:
# <AxesSubplot:xlabel='weather_code', ylabel='count'>

# %%
# with countplot

# %%
g = sns.FacetGrid(data =df_new, col = 'season')
g.map(sns.countplot, 'weather_code')
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.catplot(x = 'weather_code', col = 'season', kind = 'count', data = df_new)

# %%
# with catplot

# %% [markdown]
# ### 17.Visulaize all the continuous variables with histogram and scatterplot

# %%
fig, axs = plt.subplots(2,2, figsize=(12,8))
axs [0, 0].hist(df_new.t1, color = 'red', edgecolor = 'black')
axs [0, 1].hist(df_new.t2, edgecolor = 'black')
axs [1, 0].hist(df_new.wind_speed, color = 'cyan', edgecolor = 'black')
axs [1,1].hist(df_new.hum, color = 'white', edgecolor = 'black');

axs[0, 0].set_title("t1")
axs[0, 1].set_title("t2")
axs[1, 0].set_title("wind_speed")
axs[1, 1].set_title("humudity")
# Out:
# Text(0.5, 1.0, 'humudity')

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0  2015      1
#
#                      day_of_month  days_of_week  hour year_month  Month
# timestamp
# 2015-01-04 00:00:00            31             6     0     2015-1      1
# 2015-01-04 01:00:00            31             6     1     2015-1      1
# 2015-01-04 02:00:00            31             6     2     2015-1      1
# 2015-01-04 03:00:00            31             6     3     2015-1      1
# 2015-01-04 04:00:00            31             6     4     2015-1      1

# %%
# matplotlip hist

# %%
df_new.season.unique()
# Out:
# array([3., 0., 1., 2.])

# %%
fig, axs = plt.subplots(2,1, figsize = (15,10))
axs [0].scatter(x = df_new.t1, y = df_new.hum, c = df_new.season, cmap = 'coolwarm', lw = 0.0001)
axs [1].scatter(x = df_new.t1, y = df_new.wind_speed, c = df_new.season, cmap = 'coolwarm', lw = 0.0001)

# %%
plt.subplots(2,1, figsize = (15,10))
sns.scatterplot(x='t1', y = 'hum', data = df_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-813bd1e3c346> in <module>
# ----> 1 plt.subplots(2,1, figsize = (15,10))
#       2 sns.scatterplot(x='t1', y = 'hum', data = df_new)
#
# NameError: name 'plt' is not defined

# %%
plt.scatter()

# %%
# matplotlib scatterplot

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
